# %%
import sys
import os
import numpy as np
import lhapdf

sys.path.append("/work/JAM/dadamiak/ePump/ePump_for_LatticePDF")
sys.path.append("/work/JAM/apps/lhapdf_tables")
custom_path = "/work/JAM/apps/lhapdf_tables"
os.environ["LHAPDF_DATA_PATH"] = custom_path

from scan_window_moments import WindowMomentScanner

# %%
scanner1 = WindowMomentScanner('runcard_g_n_1_u_0.1.py')   # or pass a cfg dict directly
scanner2 = WindowMomentScanner('runcard_g_n_2_u_0.1.py') 
scanner3 = WindowMomentScanner('runcard_g_n_1_u_0.25.py')

# %%
# scanner.load()
scanner1.run()
scanner2.run()
scanner3.run()
# Out:
# Converting 'JAMDiFF23-transversity_lo_nolat' (MC replicas) → asymmetric Hessian in /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/_hessian …
#   MC-to-Hessian conversion at Q = 1.0 GeV, neig = 50, epsilon = 1000.0
# LHAPDF 6.5.4 loading all 975 PDFs in set JAMDiFF23-transversity_lo_nolat
# JAMDiFF23-transversity_lo_nolat, version 1; 975 PDF members
#   Keeping 400 / 700 points (epsilon = 1000.0)
# -> Reading replica from LHAPDF 974
#
#   Symmetric Hessian set written to /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/_hessian/JAMDiFF23-transversity_lo_nolat_hessian_50/
#   Expanded symmetric Hessian (51 members) to asymmetric pairs (101 members).
#   → 'JAMDiFF23-transversity_lo_nolat_hessian_50'
# LHAPDF 6.5.4 loading /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/_hessian/JAMDiFF23-transversity_lo_nolat_hessian_50/JAMDiFF23-transversity_lo_nolat_hessian_50_0000.dat
# JAMDiFF23-transversity_lo_nolat_hessian_50 PDF set, member #0, version 1; LHAPDF ID = 1
#
# (1/35) [mid_0.1500_wid_0.0500]  x=[0.1250, 0.1750]  central=1.13473  stat=0.113473
# LHAPDF 6.5.4 loading all 101 PDFs in set JAMDiFF23-transversity_lo_nolat_hessian_50
# JAMDiFF23-transversity_lo_nolat_hessian_50, version 1; 101 PDF members
# LHAPDF 6.5.4 loading all 101 PDFs in set JAMDiFF23-transversity_lo_nolat_hessian_50
# JAMDiFF23-transversity_lo_nolat_hessian_50, version 1; 101 PDF members
# Executing ePump profiling: /w/ceph24/JAM/dadamiak/ePump/ePump_kp20221218/src/UpdatePDFs mid_0.1500_wid_0.0500 (cwd=/w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.1500_wid_0.0500) ...
# ePump executed successfully. Parsing results from /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.1500_wid_0.0500/mid_0.1500_wid_0.0500.out...
#
# ============================================================
#                     E-PUMP PROFILING SUMMARY
# ============================================================
# Initial total Chi2 (before profiling): 0.0000
# Profiled total Chi2 (after profiling): 0.0000
# Delta Chi2 reduction:                 0.0000
#
# Predicted Observables & Uncertainties (Before vs After):
#   Obs ID   | Original Value  Original Error  | Profiled Value  Profiled Error
# --------------------------------------------------------------------------------
#   1        | 1.134700e+00    3.358500e-01    | 1.134700e+00    1.075000e-01
# ============================================================
#
# LHAPDF 6.5.4 loading all 101 PDFs in set mid_0.1500_wid_0.0500
#   Profiling complete (1/35)
# mid_0.1500_wid_0.0500, version 1; 101 PDF members
#   original  101/101
#   profiled  101/101
#   σ_before=0.33585  σ_after=0.1075  ratio=0.3201
#
# (2/35) [mid_0.1500_wid_0.0750]  x=[0.1125, 0.1875]  central=1.13075  stat=0.113075
# LHAPDF 6.5.4 loading all 101 PDFs in set JAMDiFF23-transversity_lo_nolat_hessian_50
# JAMDiFF23-transversity_lo_nolat_hessian_50, version 1; 101 PDF members
# Executing ePump profiling: /w/ceph24/JAM/dadamiak/ePump/ePump_kp20221218/src/UpdatePDFs mid_0.1500_wid_0.0750 (cwd=/w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.1500_wid_0.0750) ...
# ePump executed successfully. Parsing results from /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.1500_wid_0.0750/mid_0.1500_wid_0.0750.out...
#
# ============================================================
#                     E-PUMP PROFILING SUMMARY
# ============================================================
# Initial total Chi2 (before profiling): 0.0000
# Profiled total Chi2 (after profiling): 0.0000
# Delta Chi2 reduction:                 0.0000
#
# Predicted Observables & Uncertainties (Before vs After):
#   Obs ID   | Original Value  Original Error  | Profiled Value  Profiled Error
# --------------------------------------------------------------------------------
#   1        | 1.130700e+00    3.385100e-01    | 1.130800e+00    1.072500e-01
# ============================================================
#
# LHAPDF 6.5.4 loading all 101 PDFs in set mid_0.1500_wid_0.0750
#   Profiling complete (2/35)mid_0.1500_wid_0.0750, version 1; 101 PDF members
#
#   original  101/101
#   profiled  101/101
#   σ_before=0.33851  σ_after=0.10725  ratio=0.3168
#
# (3/35) [mid_0.1500_wid_0.1000]  x=[0.1000, 0.2000]  central=1.12501  stat=0.112501
# LHAPDF 6.5.4 loading all 101 PDFs in set JAMDiFF23-transversity_lo_nolat_hessian_50
# JAMDiFF23-transversity_lo_nolat_hessian_50, version 1; 101 PDF members
# Executing ePump profiling: /w/ceph24/JAM/dadamiak/ePump/ePump_kp20221218/src/UpdatePDFs mid_0.1500_wid_0.1000 (cwd=/w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.1500_wid_0.1000) ...
# ePump executed successfully. Parsing results from /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.1500_wid_0.1000/mid_0.1500_wid_0.1000.out...
#
# ============================================================
#                     E-PUMP PROFILING SUMMARY
# ============================================================
# Initial total Chi2 (before profiling): 0.0000
# Profiled total Chi2 (after profiling): 0.0000
# Delta Chi2 reduction:                 0.0000
#
# Predicted Observables & Uncertainties (Before vs After):
#   Obs ID   | Original Value  Original Error  | Profiled Value  Profiled Error
# --------------------------------------------------------------------------------
#   1        | 1.125000e+00    3.423200e-01    | 1.125000e+00    1.068800e-01
# ============================================================
#
# LHAPDF 6.5.4 loading all 101 PDFs in set mid_0.1500_wid_0.1000
#   Profiling complete (3/35)mid_0.1500_wid_0.1000, version 1; 101 PDF members
#
#   original  101/101
#   profiled  101/101
#   σ_before=0.34232  σ_after=0.10688  ratio=0.3122
#
# (4/35) [mid_0.1500_wid_0.1250]  x=[0.0875, 0.2125]  central=1.11733  stat=0.111733
# LHAPDF 6.5.4 loading all 101 PDFs in set JAMDiFF23-transversity_lo_nolat_hessian_50
# JAMDiFF23-transversity_lo_nolat_hessian_50, version 1; 101 PDF members
# Executing ePump profiling: /w/ceph24/JAM/dadamiak/ePump/ePump_kp20221218/src/UpdatePDFs mid_0.1500_wid_0.1250 (cwd=/w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.1500_wid_0.1250) ...
# ePump executed successfully. Parsing results from /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.1500_wid_0.1250/mid_0.1500_wid_0.1250.out...
#
# ============================================================
#                     E-PUMP PROFILING SUMMARY
# ============================================================
# Initial total Chi2 (before profiling): 0.0000
# Profiled total Chi2 (after profiling): 0.0000
# Delta Chi2 reduction:                 0.0000
#
# Predicted Observables & Uncertainties (Before vs After):
#   Obs ID   | Original Value  Original Error  | Profiled Value  Profiled Error
# --------------------------------------------------------------------------------
#   1        | 1.117300e+00    3.473600e-01    | 1.117300e+00    1.063700e-01
# ============================================================
#
# LHAPDF 6.5.4 loading all 101 PDFs in set mid_0.1500_wid_0.1250
#   Profiling complete (4/35)mid_0.1500_wid_0.1250, version 1; 101 PDF members
#
#   original  101/101
#   profiled  101/101
#   σ_before=0.34736  σ_after=0.10637  ratio=0.3062
#
# (5/35) [mid_0.1500_wid_0.1500]  x=[0.0750, 0.2250]  central=1.10746  stat=0.110746
# LHAPDF 6.5.4 loading all 101 PDFs in set JAMDiFF23-transversity_lo_nolat_hessian_50
# JAMDiFF23-transversity_lo_nolat_hessian_50, version 1; 101 PDF members
# Executing ePump profiling: /w/ceph24/JAM/dadamiak/ePump/ePump_kp20221218/src/UpdatePDFs mid_0.1500_wid_0.1500 (cwd=/w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.1500_wid_0.1500) ...
# ePump executed successfully. Parsing results from /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.1500_wid_0.1500/mid_0.1500_wid_0.1500.out...
#
# ============================================================
#                     E-PUMP PROFILING SUMMARY
# ============================================================
# Initial total Chi2 (before profiling): 0.0000
# Profiled total Chi2 (after profiling): 0.0000
# Delta Chi2 reduction:                 0.0000
#
# Predicted Observables & Uncertainties (Before vs After):
#   Obs ID   | Original Value  Original Error  | Profiled Value  Profiled Error
# --------------------------------------------------------------------------------
#   1        | 1.107500e+00    3.537000e-01    | 1.107500e+00    1.056900e-01
# ============================================================
#
# LHAPDF 6.5.4 loading all 101 PDFs in set mid_0.1500_wid_0.1500
#   Profiling complete (5/35)mid_0.1500_wid_0.1500, version 1; 101 PDF members
#
#   original  101/101
#   profiled  101/101
#   σ_before=0.3537  σ_after=0.10569  ratio=0.2988
#
# (6/35) [mid_0.2000_wid_0.0500]  x=[0.1750, 0.2250]  central=0.953971  stat=0.0953971
# LHAPDF 6.5.4 loading all 101 PDFs in set JAMDiFF23-transversity_lo_nolat_hessian_50
# JAMDiFF23-transversity_lo_nolat_hessian_50, version 1; 101 PDF members
# Executing ePump profiling: /w/ceph24/JAM/dadamiak/ePump/ePump_kp20221218/src/UpdatePDFs mid_0.2000_wid_0.0500 (cwd=/w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.2000_wid_0.0500) ...
# ePump executed successfully. Parsing results from /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.2000_wid_0.0500/mid_0.2000_wid_0.0500.out...
#
# ============================================================
#                     E-PUMP PROFILING SUMMARY
# ============================================================
# Initial total Chi2 (before profiling): 0.0000
# Profiled total Chi2 (after profiling): 0.0000
# Delta Chi2 reduction:                 0.0000
#
# Predicted Observables & Uncertainties (Before vs After):
#   Obs ID   | Original Value  Original Error  | Profiled Value  Profiled Error
# --------------------------------------------------------------------------------
#   1        | 9.539700e-01    2.070700e-01    | 9.539700e-01    8.664400e-02
# ============================================================
#
# LHAPDF 6.5.4 loading all 101 PDFs in set mid_0.2000_wid_0.0500
#   Profiling complete (6/35)mid_0.2000_wid_0.0500, version 1; 101 PDF members
#
#   original  101/101
#   profiled  101/101
#   σ_before=0.20707  σ_after=0.086644  ratio=0.4184
#
# (7/35) [mid_0.2000_wid_0.0750]  x=[0.1625, 0.2375]  central=0.953174  stat=0.0953174
# LHAPDF 6.5.4 loading all 101 PDFs in set JAMDiFF23-transversity_lo_nolat_hessian_50
# JAMDiFF23-transversity_lo_nolat_hessian_50, version 1; 101 PDF members
# Executing ePump profiling: /w/ceph24/JAM/dadamiak/ePump/ePump_kp20221218/src/UpdatePDFs mid_0.2000_wid_0.0750 (cwd=/w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.2000_wid_0.0750) ...
# ePump executed successfully. Parsing results from /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.2000_wid_0.0750/mid_0.2000_wid_0.0750.out...
#
# ============================================================
#                     E-PUMP PROFILING SUMMARY
# ============================================================
# Initial total Chi2 (before profiling): 0.0000
# Profiled total Chi2 (after profiling): 0.0000
# Delta Chi2 reduction:                 0.0000
#
# Predicted Observables & Uncertainties (Before vs After):
#   Obs ID   | Original Value  Original Error  | Profiled Value  Profiled Error
# --------------------------------------------------------------------------------
#   1        | 9.531700e-01    2.084300e-01    | 9.531700e-01    8.668300e-02
# ============================================================
#
# LHAPDF 6.5.4 loading all 101 PDFs in set mid_0.2000_wid_0.0750
#   Profiling complete (7/35)
# mid_0.2000_wid_0.0750, version 1; 101 PDF members
#   original  101/101
#   profiled  101/101
#   σ_before=0.20843  σ_after=0.086684  ratio=0.4159
#
# (8/35) [mid_0.2000_wid_0.1000]  x=[0.1500, 0.2500]  central=0.951979  stat=0.0951979
# LHAPDF 6.5.4 loading all 101 PDFs in set JAMDiFF23-transversity_lo_nolat_hessian_50
# JAMDiFF23-transversity_lo_nolat_hessian_50, version 1; 101 PDF members
# Executing ePump profiling: /w/ceph24/JAM/dadamiak/ePump/ePump_kp20221218/src/UpdatePDFs mid_0.2000_wid_0.1000 (cwd=/w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.2000_wid_0.1000) ...
# ePump executed successfully. Parsing results from /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.2000_wid_0.1000/mid_0.2000_wid_0.1000.out...
#
# ============================================================
#                     E-PUMP PROFILING SUMMARY
# ============================================================
# Initial total Chi2 (before profiling): 0.0000
# Profiled total Chi2 (after profiling): 0.0000
# Delta Chi2 reduction:                 0.0000
#
# Predicted Observables & Uncertainties (Before vs After):
#   Obs ID   | Original Value  Original Error  | Profiled Value  Profiled Error
# --------------------------------------------------------------------------------
#   1        | 9.519800e-01    2.103900e-01    | 9.519800e-01    8.673200e-02
# ============================================================
#
# LHAPDF 6.5.4 loading all 101 PDFs in set mid_0.2000_wid_0.1000
#   Profiling complete (8/35)
# mid_0.2000_wid_0.1000, version 1; 101 PDF members
#   original  101/101
#   profiled  101/101
#   σ_before=0.21039  σ_after=0.086732  ratio=0.4122
#
# (9/35) [mid_0.2000_wid_0.1250]  x=[0.1375, 0.2625]  central=0.950308  stat=0.0950308
# LHAPDF 6.5.4 loading all 101 PDFs in set JAMDiFF23-transversity_lo_nolat_hessian_50
# JAMDiFF23-transversity_lo_nolat_hessian_50, version 1; 101 PDF members
# Executing ePump profiling: /w/ceph24/JAM/dadamiak/ePump/ePump_kp20221218/src/UpdatePDFs mid_0.2000_wid_0.1250 (cwd=/w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.2000_wid_0.1250) ...
# ePump executed successfully. Parsing results from /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.2000_wid_0.1250/mid_0.2000_wid_0.1250.out...
#
# ============================================================
#                     E-PUMP PROFILING SUMMARY
# ============================================================
# Initial total Chi2 (before profiling): 0.0000
# Profiled total Chi2 (after profiling): 0.0000
# Delta Chi2 reduction:                 0.0000
#
# Predicted Observables & Uncertainties (Before vs After):
#   Obs ID   | Original Value  Original Error  | Profiled Value  Profiled Error
# --------------------------------------------------------------------------------
#   1        | 9.503100e-01    2.130200e-01    | 9.503100e-01    8.678600e-02
# ============================================================
#
# LHAPDF 6.5.4 loading all 101 PDFs in set mid_0.2000_wid_0.1250
#   Profiling complete (9/35)mid_0.2000_wid_0.1250, version 1; 101 PDF members
#
#   original  101/101
#   profiled  101/101
#   σ_before=0.21302  σ_after=0.086786  ratio=0.4074
#
# (10/35) [mid_0.2000_wid_0.1500]  x=[0.1250, 0.2750]  central=0.948053  stat=0.0948053
# LHAPDF 6.5.4 loading all 101 PDFs in set JAMDiFF23-transversity_lo_nolat_hessian_50
# JAMDiFF23-transversity_lo_nolat_hessian_50, version 1; 101 PDF members
# Executing ePump profiling: /w/ceph24/JAM/dadamiak/ePump/ePump_kp20221218/src/UpdatePDFs mid_0.2000_wid_0.1500 (cwd=/w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.2000_wid_0.1500) ...
# ePump executed successfully. Parsing results from /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.2000_wid_0.1500/mid_0.2000_wid_0.1500.out...
#
# ============================================================
#                     E-PUMP PROFILING SUMMARY
# ============================================================
# Initial total Chi2 (before profiling): 0.0000
# Profiled total Chi2 (after profiling): 0.0000
# Delta Chi2 reduction:                 0.0000
#
# Predicted Observables & Uncertainties (Before vs After):
#   Obs ID   | Original Value  Original Error  | Profiled Value  Profiled Error
# --------------------------------------------------------------------------------
#   1        | 9.480500e-01    2.163800e-01    | 9.480500e-01    8.683600e-02
# ============================================================
#
# LHAPDF 6.5.4 loading all 101 PDFs in set mid_0.2000_wid_0.1500
#   Profiling complete (10/35)mid_0.2000_wid_0.1500, version 1; 101 PDF members
#
#   original  101/101
#   profiled  101/101
#   σ_before=0.21638  σ_after=0.086836  ratio=0.4013
#
# (11/35) [mid_0.2500_wid_0.0500]  x=[0.2250, 0.2750]  central=0.75281  stat=0.075281
# LHAPDF 6.5.4 loading all 101 PDFs in set JAMDiFF23-transversity_lo_nolat_hessian_50
# JAMDiFF23-transversity_lo_nolat_hessian_50, version 1; 101 PDF members
# Executing ePump profiling: /w/ceph24/JAM/dadamiak/ePump/ePump_kp20221218/src/UpdatePDFs mid_0.2500_wid_0.0500 (cwd=/w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.2500_wid_0.0500) ...
# ePump executed successfully. Parsing results from /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.2500_wid_0.0500/mid_0.2500_wid_0.0500.out...
#
# ============================================================
#                     E-PUMP PROFILING SUMMARY
# ============================================================
# Initial total Chi2 (before profiling): 0.0000
# Profiled total Chi2 (after profiling): 0.0000
# Delta Chi2 reduction:                 0.0000
#
# Predicted Observables & Uncertainties (Before vs After):
#   Obs ID   | Original Value  Original Error  | Profiled Value  Profiled Error
# --------------------------------------------------------------------------------
#   1        | 7.528100e-01    1.427500e-01    | 7.528100e-01    6.658800e-02
# ============================================================
#
# LHAPDF 6.5.4 loading all 101 PDFs in set mid_0.2500_wid_0.0500
#   Profiling complete (11/35)
# mid_0.2500_wid_0.0500, version 1; 101 PDF members
#   original  101/101
#   profiled  101/101
#   σ_before=0.14275  σ_after=0.066588  ratio=0.4665
#
# (12/35) [mid_0.2500_wid_0.0750]  x=[0.2125, 0.2875]  central=0.753538  stat=0.0753538
# LHAPDF 6.5.4 loading all 101 PDFs in set JAMDiFF23-transversity_lo_nolat_hessian_50
# JAMDiFF23-transversity_lo_nolat_hessian_50, version 1; 101 PDF members
# Executing ePump profiling: /w/ceph24/JAM/dadamiak/ePump/ePump_kp20221218/src/UpdatePDFs mid_0.2500_wid_0.0750 (cwd=/w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.2500_wid_0.0750) ...
# ePump executed successfully. Parsing results from /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.2500_wid_0.0750/mid_0.2500_wid_0.0750.out...
#
# ============================================================
#                     E-PUMP PROFILING SUMMARY
# ============================================================
# Initial total Chi2 (before profiling): 0.0000
# Profiled total Chi2 (after profiling): 0.0000
# Delta Chi2 reduction:                 0.0000
#
# Predicted Observables & Uncertainties (Before vs After):
#   Obs ID   | Original Value  Original Error  | Profiled Value  Profiled Error
# --------------------------------------------------------------------------------
#   1        | 7.535400e-01    1.431500e-01    | 7.535400e-01    6.668000e-02
# ============================================================
#
# LHAPDF 6.5.4 loading all 101 PDFs in set mid_0.2500_wid_0.0750
#   Profiling complete (12/35)mid_0.2500_wid_0.0750, version 1; 101 PDF members
#
#   original  101/101
#   profiled  101/101
#   σ_before=0.14315  σ_after=0.06668  ratio=0.4658
#
# (13/35) [mid_0.2500_wid_0.1000]  x=[0.2000, 0.3000]  central=0.754513  stat=0.0754513
# LHAPDF 6.5.4 loading all 101 PDFs in set JAMDiFF23-transversity_lo_nolat_hessian_50
# JAMDiFF23-transversity_lo_nolat_hessian_50, version 1; 101 PDF members
# Executing ePump profiling: /w/ceph24/JAM/dadamiak/ePump/ePump_kp20221218/src/UpdatePDFs mid_0.2500_wid_0.1000 (cwd=/w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.2500_wid_0.1000) ...
# ePump executed successfully. Parsing results from /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.2500_wid_0.1000/mid_0.2500_wid_0.1000.out...
#
# ============================================================
#                     E-PUMP PROFILING SUMMARY
# ============================================================
# Initial total Chi2 (before profiling): 0.0000
# Profiled total Chi2 (after profiling): 0.0000
# Delta Chi2 reduction:                 0.0000
#
# Predicted Observables & Uncertainties (Before vs After):
#   Obs ID   | Original Value  Original Error  | Profiled Value  Profiled Error
# --------------------------------------------------------------------------------
#   1        | 7.545100e-01    1.437600e-01    | 7.545100e-01    6.680900e-02
# ============================================================
#
# LHAPDF 6.5.4 loading all 101 PDFs in set mid_0.2500_wid_0.1000
#   Profiling complete (13/35)mid_0.2500_wid_0.1000, version 1; 101 PDF members
#
#   original  101/101
#   profiled  101/101
#   σ_before=0.14376  σ_after=0.066809  ratio=0.4647
#
# (14/35) [mid_0.2500_wid_0.1250]  x=[0.1875, 0.3125]  central=0.755691  stat=0.0755691
# LHAPDF 6.5.4 loading all 101 PDFs in set JAMDiFF23-transversity_lo_nolat_hessian_50
# JAMDiFF23-transversity_lo_nolat_hessian_50, version 1; 101 PDF members
# Executing ePump profiling: /w/ceph24/JAM/dadamiak/ePump/ePump_kp20221218/src/UpdatePDFs mid_0.2500_wid_0.1250 (cwd=/w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.2500_wid_0.1250) ...
# ePump executed successfully. Parsing results from /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.2500_wid_0.1250/mid_0.2500_wid_0.1250.out...
#
# ============================================================
#                     E-PUMP PROFILING SUMMARY
# ============================================================
# Initial total Chi2 (before profiling): 0.0000
# Profiled total Chi2 (after profiling): 0.0000
# Delta Chi2 reduction:                 0.0000
#
# Predicted Observables & Uncertainties (Before vs After):
#   Obs ID   | Original Value  Original Error  | Profiled Value  Profiled Error
# --------------------------------------------------------------------------------
#   1        | 7.556900e-01    1.446100e-01    | 7.556900e-01    6.697600e-02
# ============================================================
#
# LHAPDF 6.5.4 loading all 101 PDFs in set mid_0.2500_wid_0.1250
#   Profiling complete (14/35)
# mid_0.2500_wid_0.1250, version 1; 101 PDF members
#   original  101/101
#   profiled  101/101
#   σ_before=0.14461  σ_after=0.066976  ratio=0.4631
#
# (15/35) [mid_0.2500_wid_0.1500]  x=[0.1750, 0.3250]  central=0.757019  stat=0.0757019
# LHAPDF 6.5.4 loading all 101 PDFs in set JAMDiFF23-transversity_lo_nolat_hessian_50
# JAMDiFF23-transversity_lo_nolat_hessian_50, version 1; 101 PDF members
# Executing ePump profiling: /w/ceph24/JAM/dadamiak/ePump/ePump_kp20221218/src/UpdatePDFs mid_0.2500_wid_0.1500 (cwd=/w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.2500_wid_0.1500) ...
# ePump executed successfully. Parsing results from /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.2500_wid_0.1500/mid_0.2500_wid_0.1500.out...
#
# ============================================================
#                     E-PUMP PROFILING SUMMARY
# ============================================================
# Initial total Chi2 (before profiling): 0.0000
# Profiled total Chi2 (after profiling): 0.0000
# Delta Chi2 reduction:                 0.0000
#
# Predicted Observables & Uncertainties (Before vs After):
#   Obs ID   | Original Value  Original Error  | Profiled Value  Profiled Error
# --------------------------------------------------------------------------------
#   1        | 7.570200e-01    1.457700e-01    | 7.570200e-01    6.718300e-02
# ============================================================
#
# LHAPDF 6.5.4 loading all 101 PDFs in set mid_0.2500_wid_0.1500
#   Profiling complete (15/35)mid_0.2500_wid_0.1500, version 1; 101 PDF members
#
#   original  101/101
#   profiled  101/101
#   σ_before=0.14577  σ_after=0.067183  ratio=0.4609
#
# (16/35) [mid_0.3000_wid_0.0500]  x=[0.2750, 0.3250]  central=0.566058  stat=0.0566058
# LHAPDF 6.5.4 loading all 101 PDFs in set JAMDiFF23-transversity_lo_nolat_hessian_50
# JAMDiFF23-transversity_lo_nolat_hessian_50, version 1; 101 PDF members
# Executing ePump profiling: /w/ceph24/JAM/dadamiak/ePump/ePump_kp20221218/src/UpdatePDFs mid_0.3000_wid_0.0500 (cwd=/w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.3000_wid_0.0500) ...
# ePump executed successfully. Parsing results from /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.3000_wid_0.0500/mid_0.3000_wid_0.0500.out...
#
# ============================================================
#                     E-PUMP PROFILING SUMMARY
# ============================================================
# Initial total Chi2 (before profiling): 0.0000
# Profiled total Chi2 (after profiling): 0.0000
# Delta Chi2 reduction:                 0.0000
#
# Predicted Observables & Uncertainties (Before vs After):
#   Obs ID   | Original Value  Original Error  | Profiled Value  Profiled Error
# --------------------------------------------------------------------------------
#   1        | 5.660600e-01    1.153200e-01    | 5.660600e-01    5.081400e-02
# ============================================================
#
# LHAPDF 6.5.4 loading all 101 PDFs in set mid_0.3000_wid_0.0500
#   Profiling complete (16/35)
# mid_0.3000_wid_0.0500, version 1; 101 PDF members
#   original  101/101
#   profiled  101/101
#   σ_before=0.11532  σ_after=0.050814  ratio=0.4406
#
# (17/35) [mid_0.3000_wid_0.0750]  x=[0.2625, 0.3375]  central=0.567419  stat=0.0567419
# LHAPDF 6.5.4 loading all 101 PDFs in set JAMDiFF23-transversity_lo_nolat_hessian_50
# JAMDiFF23-transversity_lo_nolat_hessian_50, version 1; 101 PDF members
# Executing ePump profiling: /w/ceph24/JAM/dadamiak/ePump/ePump_kp20221218/src/UpdatePDFs mid_0.3000_wid_0.0750 (cwd=/w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.3000_wid_0.0750) ...
# ePump executed successfully. Parsing results from /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.3000_wid_0.0750/mid_0.3000_wid_0.0750.out...
#
# ============================================================
#                     E-PUMP PROFILING SUMMARY
# ============================================================
# Initial total Chi2 (before profiling): 0.0000
# Profiled total Chi2 (after profiling): 0.0000
# Delta Chi2 reduction:                 0.0000
#
# Predicted Observables & Uncertainties (Before vs After):
#   Obs ID   | Original Value  Original Error  | Profiled Value  Profiled Error
# --------------------------------------------------------------------------------
#   1        | 5.674200e-01    1.151800e-01    | 5.674200e-01    5.090000e-02
# ============================================================
#
# LHAPDF 6.5.4 loading all 101 PDFs in set mid_0.3000_wid_0.0750
#   Profiling complete (17/35)mid_0.3000_wid_0.0750, version 1; 101 PDF members
#
#   original  101/101
#   profiled  101/101
#   σ_before=0.11518  σ_after=0.050901  ratio=0.4419
#
# (18/35) [mid_0.3000_wid_0.1000]  x=[0.2500, 0.3500]  central=0.569302  stat=0.0569302
# LHAPDF 6.5.4 loading all 101 PDFs in set JAMDiFF23-transversity_lo_nolat_hessian_50
# JAMDiFF23-transversity_lo_nolat_hessian_50, version 1; 101 PDF members
# Executing ePump profiling: /w/ceph24/JAM/dadamiak/ePump/ePump_kp20221218/src/UpdatePDFs mid_0.3000_wid_0.1000 (cwd=/w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.3000_wid_0.1000) ...
# ePump executed successfully. Parsing results from /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.3000_wid_0.1000/mid_0.3000_wid_0.1000.out...
#
# ============================================================
#                     E-PUMP PROFILING SUMMARY
# ============================================================
# Initial total Chi2 (before profiling): 0.0000
# Profiled total Chi2 (after profiling): 0.0000
# Delta Chi2 reduction:                 0.0000
#
# Predicted Observables & Uncertainties (Before vs After):
#   Obs ID   | Original Value  Original Error  | Profiled Value  Profiled Error
# --------------------------------------------------------------------------------
#   1        | 5.693000e-01    1.150100e-01    | 5.693000e-01    5.102100e-02
# ============================================================
#
# LHAPDF 6.5.4 loading all 101 PDFs in set mid_0.3000_wid_0.1000
#   Profiling complete (18/35)
# mid_0.3000_wid_0.1000, version 1; 101 PDF members
#   original  101/101
#   profiled  101/101
#   σ_before=0.11501  σ_after=0.051021  ratio=0.4436
#
# (19/35) [mid_0.3000_wid_0.1250]  x=[0.2375, 0.3625]  central=0.571682  stat=0.0571682
# LHAPDF 6.5.4 loading all 101 PDFs in set JAMDiFF23-transversity_lo_nolat_hessian_50
# JAMDiFF23-transversity_lo_nolat_hessian_50, version 1; 101 PDF members
# Executing ePump profiling: /w/ceph24/JAM/dadamiak/ePump/ePump_kp20221218/src/UpdatePDFs mid_0.3000_wid_0.1250 (cwd=/w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.3000_wid_0.1250) ...
# ePump executed successfully. Parsing results from /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.3000_wid_0.1250/mid_0.3000_wid_0.1250.out...
#
# ============================================================
#                     E-PUMP PROFILING SUMMARY
# ============================================================
# Initial total Chi2 (before profiling): 0.0000
# Profiled total Chi2 (after profiling): 0.0000
# Delta Chi2 reduction:                 0.0000
#
# Predicted Observables & Uncertainties (Before vs After):
#   Obs ID   | Original Value  Original Error  | Profiled Value  Profiled Error
# --------------------------------------------------------------------------------
#   1        | 5.716800e-01    1.148300e-01    | 5.716800e-01    5.117700e-02
# ============================================================
#
# LHAPDF 6.5.4 loading all 101 PDFs in set mid_0.3000_wid_0.1250
#   Profiling complete (19/35)
# mid_0.3000_wid_0.1250, version 1; 101 PDF members
#   original  101/101
#   profiled  101/101
#   σ_before=0.11483  σ_after=0.051177  ratio=0.4457
#
# (20/35) [mid_0.3000_wid_0.1500]  x=[0.2250, 0.3750]  central=0.574528  stat=0.0574528
# LHAPDF 6.5.4 loading all 101 PDFs in set JAMDiFF23-transversity_lo_nolat_hessian_50
# JAMDiFF23-transversity_lo_nolat_hessian_50, version 1; 101 PDF members
# Executing ePump profiling: /w/ceph24/JAM/dadamiak/ePump/ePump_kp20221218/src/UpdatePDFs mid_0.3000_wid_0.1500 (cwd=/w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.3000_wid_0.1500) ...
# ePump executed successfully. Parsing results from /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.3000_wid_0.1500/mid_0.3000_wid_0.1500.out...
#
# ============================================================
#                     E-PUMP PROFILING SUMMARY
# ============================================================
# Initial total Chi2 (before profiling): 0.0000
# Profiled total Chi2 (after profiling): 0.0000
# Delta Chi2 reduction:                 0.0000
#
# Predicted Observables & Uncertainties (Before vs After):
#   Obs ID   | Original Value  Original Error  | Profiled Value  Profiled Error
# --------------------------------------------------------------------------------
#   1        | 5.745300e-01    1.146800e-01    | 5.745300e-01    5.136700e-02
# ============================================================
#
# LHAPDF 6.5.4 loading all 101 PDFs in set mid_0.3000_wid_0.1500
#   Profiling complete (20/35)mid_0.3000_wid_0.1500, version 1; 101 PDF members
#
#   original  101/101
#   profiled  101/101
#   σ_before=0.11468  σ_after=0.051367  ratio=0.4479
#
# (21/35) [mid_0.3500_wid_0.0500]  x=[0.3250, 0.3750]  central=0.408367  stat=0.0408367
# LHAPDF 6.5.4 loading all 101 PDFs in set JAMDiFF23-transversity_lo_nolat_hessian_50
# JAMDiFF23-transversity_lo_nolat_hessian_50, version 1; 101 PDF members
# Executing ePump profiling: /w/ceph24/JAM/dadamiak/ePump/ePump_kp20221218/src/UpdatePDFs mid_0.3500_wid_0.0500 (cwd=/w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.3500_wid_0.0500) ...
# ePump executed successfully. Parsing results from /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.3500_wid_0.0500/mid_0.3500_wid_0.0500.out...
#
# ============================================================
#                     E-PUMP PROFILING SUMMARY
# ============================================================
# Initial total Chi2 (before profiling): 0.0000
# Profiled total Chi2 (after profiling): 0.0000
# Delta Chi2 reduction:                 0.0000
#
# Predicted Observables & Uncertainties (Before vs After):
#   Obs ID   | Original Value  Original Error  | Profiled Value  Profiled Error
# --------------------------------------------------------------------------------
#   1        | 4.083700e-01    1.018600e-01    | 4.083700e-01    3.790400e-02
# ============================================================
#
# LHAPDF 6.5.4 loading all 101 PDFs in set mid_0.3500_wid_0.0500
#   Profiling complete (21/35)mid_0.3500_wid_0.0500, version 1; 101 PDF members
#
#   original  101/101
#   profiled  101/101
#   σ_before=0.10186  σ_after=0.037904  ratio=0.3721
#
# (22/35) [mid_0.3500_wid_0.0750]  x=[0.3125, 0.3875]  central=0.409878  stat=0.0409878
# LHAPDF 6.5.4 loading all 101 PDFs in set JAMDiFF23-transversity_lo_nolat_hessian_50
# JAMDiFF23-transversity_lo_nolat_hessian_50, version 1; 101 PDF members
# Executing ePump profiling: /w/ceph24/JAM/dadamiak/ePump/ePump_kp20221218/src/UpdatePDFs mid_0.3500_wid_0.0750 (cwd=/w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.3500_wid_0.0750) ...
# ePump executed successfully. Parsing results from /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.3500_wid_0.0750/mid_0.3500_wid_0.0750.out...
#
# ============================================================
#                     E-PUMP PROFILING SUMMARY
# ============================================================
# Initial total Chi2 (before profiling): 0.0000
# Profiled total Chi2 (after profiling): 0.0000
# Delta Chi2 reduction:                 0.0000
#
# Predicted Observables & Uncertainties (Before vs After):
#   Obs ID   | Original Value  Original Error  | Profiled Value  Profiled Error
# --------------------------------------------------------------------------------
#   1        | 4.098800e-01    1.015800e-01    | 4.098800e-01    3.801000e-02
# ============================================================
#
# LHAPDF 6.5.4 loading all 101 PDFs in set mid_0.3500_wid_0.0750
#   Profiling complete (22/35)mid_0.3500_wid_0.0750, version 1; 101 PDF members
#
#   original  101/101
#   profiled  101/101
#   σ_before=0.10158  σ_after=0.03801  ratio=0.3742
#
# (23/35) [mid_0.3500_wid_0.1000]  x=[0.3000, 0.4000]  central=0.41198  stat=0.041198
# LHAPDF 6.5.4 loading all 101 PDFs in set JAMDiFF23-transversity_lo_nolat_hessian_50
# JAMDiFF23-transversity_lo_nolat_hessian_50, version 1; 101 PDF members
# Executing ePump profiling: /w/ceph24/JAM/dadamiak/ePump/ePump_kp20221218/src/UpdatePDFs mid_0.3500_wid_0.1000 (cwd=/w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.3500_wid_0.1000) ...
# ePump executed successfully. Parsing results from /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.3500_wid_0.1000/mid_0.3500_wid_0.1000.out...
#
# ============================================================
#                     E-PUMP PROFILING SUMMARY
# ============================================================
# Initial total Chi2 (before profiling): 0.0000
# Profiled total Chi2 (after profiling): 0.0000
# Delta Chi2 reduction:                 0.0000
#
# Predicted Observables & Uncertainties (Before vs After):
#   Obs ID   | Original Value  Original Error  | Profiled Value  Profiled Error
# --------------------------------------------------------------------------------
#   1        | 4.119800e-01    1.011900e-01    | 4.119800e-01    3.815700e-02
# ============================================================
#
# LHAPDF 6.5.4 loading all 101 PDFs in set mid_0.3500_wid_0.1000
#   Profiling complete (23/35)mid_0.3500_wid_0.1000, version 1; 101 PDF members
#
#   original  101/101
#   profiled  101/101
#   σ_before=0.10119  σ_after=0.038157  ratio=0.3771
#
# (24/35) [mid_0.3500_wid_0.1250]  x=[0.2875, 0.4125]  central=0.414662  stat=0.0414662
# LHAPDF 6.5.4 loading all 101 PDFs in set JAMDiFF23-transversity_lo_nolat_hessian_50
# JAMDiFF23-transversity_lo_nolat_hessian_50, version 1; 101 PDF members
# Executing ePump profiling: /w/ceph24/JAM/dadamiak/ePump/ePump_kp20221218/src/UpdatePDFs mid_0.3500_wid_0.1250 (cwd=/w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.3500_wid_0.1250) ...
# ePump executed successfully. Parsing results from /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.3500_wid_0.1250/mid_0.3500_wid_0.1250.out...
#
# ============================================================
#                     E-PUMP PROFILING SUMMARY
# ============================================================
# Initial total Chi2 (before profiling): 0.0000
# Profiled total Chi2 (after profiling): 0.0000
# Delta Chi2 reduction:                 0.0000
#
# Predicted Observables & Uncertainties (Before vs After):
#   Obs ID   | Original Value  Original Error  | Profiled Value  Profiled Error
# --------------------------------------------------------------------------------
#   1        | 4.146600e-01    1.007100e-01    | 4.146600e-01    3.834300e-02
# ============================================================
#
# LHAPDF 6.5.4 loading all 101 PDFs in set mid_0.3500_wid_0.1250
#   Profiling complete (24/35)mid_0.3500_wid_0.1250, version 1; 101 PDF members
#
#   original  101/101
#   profiled  101/101
#   σ_before=0.10071  σ_after=0.038344  ratio=0.3807
#
# (25/35) [mid_0.3500_wid_0.1500]  x=[0.2750, 0.4250]  central=0.417909  stat=0.0417909
# LHAPDF 6.5.4 loading all 101 PDFs in set JAMDiFF23-transversity_lo_nolat_hessian_50
# JAMDiFF23-transversity_lo_nolat_hessian_50, version 1; 101 PDF members
# Executing ePump profiling: /w/ceph24/JAM/dadamiak/ePump/ePump_kp20221218/src/UpdatePDFs mid_0.3500_wid_0.1500 (cwd=/w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.3500_wid_0.1500) ...
# ePump executed successfully. Parsing results from /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.3500_wid_0.1500/mid_0.3500_wid_0.1500.out...
#
# ============================================================
#                     E-PUMP PROFILING SUMMARY
# ============================================================
# Initial total Chi2 (before profiling): 0.0000
# Profiled total Chi2 (after profiling): 0.0000
# Delta Chi2 reduction:                 0.0000
#
# Predicted Observables & Uncertainties (Before vs After):
#   Obs ID   | Original Value  Original Error  | Profiled Value  Profiled Error
# --------------------------------------------------------------------------------
#   1        | 4.179100e-01    1.001500e-01    | 4.179100e-01    3.856800e-02
# ============================================================
#
# LHAPDF 6.5.4 loading all 101 PDFs in set mid_0.3500_wid_0.1500
#   Profiling complete (25/35)
# mid_0.3500_wid_0.1500, version 1; 101 PDF members
#   original  101/101
#   profiled  101/101
#   σ_before=0.10015  σ_after=0.038568  ratio=0.3851
#
# (26/35) [mid_0.4000_wid_0.0500]  x=[0.3750, 0.4250]  central=0.283432  stat=0.0283432
# LHAPDF 6.5.4 loading all 101 PDFs in set JAMDiFF23-transversity_lo_nolat_hessian_50
# JAMDiFF23-transversity_lo_nolat_hessian_50, version 1; 101 PDF members
# Executing ePump profiling: /w/ceph24/JAM/dadamiak/ePump/ePump_kp20221218/src/UpdatePDFs mid_0.4000_wid_0.0500 (cwd=/w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.4000_wid_0.0500) ...
# ePump executed successfully. Parsing results from /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.4000_wid_0.0500/mid_0.4000_wid_0.0500.out...
#
# ============================================================
#                     E-PUMP PROFILING SUMMARY
# ============================================================
# Initial total Chi2 (before profiling): 0.0000
# Profiled total Chi2 (after profiling): 0.0000
# Delta Chi2 reduction:                 0.0000
#
# Predicted Observables & Uncertainties (Before vs After):
#   Obs ID   | Original Value  Original Error  | Profiled Value  Profiled Error
# --------------------------------------------------------------------------------
#   1        | 2.834300e-01    8.996400e-02    | 2.834300e-01    2.703300e-02
# ============================================================
#
# LHAPDF 6.5.4 loading all 101 PDFs in set mid_0.4000_wid_0.0500
#   Profiling complete (26/35)
# mid_0.4000_wid_0.0500, version 1; 101 PDF members
#   original  101/101
#   profiled  101/101
#   σ_before=0.089964  σ_after=0.027033  ratio=0.3005
#
# (27/35) [mid_0.4000_wid_0.0750]  x=[0.3625, 0.4375]  central=0.28484  stat=0.028484
# LHAPDF 6.5.4 loading all 101 PDFs in set JAMDiFF23-transversity_lo_nolat_hessian_50
# JAMDiFF23-transversity_lo_nolat_hessian_50, version 1; 101 PDF members
# Executing ePump profiling: /w/ceph24/JAM/dadamiak/ePump/ePump_kp20221218/src/UpdatePDFs mid_0.4000_wid_0.0750 (cwd=/w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.4000_wid_0.0750) ...
# ePump executed successfully. Parsing results from /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.4000_wid_0.0750/mid_0.4000_wid_0.0750.out...
#
# ============================================================
#                     E-PUMP PROFILING SUMMARY
# ============================================================
# Initial total Chi2 (before profiling): 0.0000
# Profiled total Chi2 (after profiling): 0.0000
# Delta Chi2 reduction:                 0.0000
#
# Predicted Observables & Uncertainties (Before vs After):
#   Obs ID   | Original Value  Original Error  | Profiled Value  Profiled Error
# --------------------------------------------------------------------------------
#   1        | 2.848400e-01    8.973400e-02    | 2.848400e-01    2.714900e-02
# ============================================================
#
# LHAPDF 6.5.4 loading all 101 PDFs in set mid_0.4000_wid_0.0750
#   Profiling complete (27/35)mid_0.4000_wid_0.0750, version 1; 101 PDF members
#
#   original  101/101
#   profiled  101/101
#   σ_before=0.089734  σ_after=0.027149  ratio=0.3025
#
# (28/35) [mid_0.4000_wid_0.1000]  x=[0.3500, 0.4500]  central=0.286808  stat=0.0286808
# LHAPDF 6.5.4 loading all 101 PDFs in set JAMDiFF23-transversity_lo_nolat_hessian_50
# JAMDiFF23-transversity_lo_nolat_hessian_50, version 1; 101 PDF members
# Executing ePump profiling: /w/ceph24/JAM/dadamiak/ePump/ePump_kp20221218/src/UpdatePDFs mid_0.4000_wid_0.1000 (cwd=/w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.4000_wid_0.1000) ...
# ePump executed successfully. Parsing results from /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.4000_wid_0.1000/mid_0.4000_wid_0.1000.out...
#
# ============================================================
#                     E-PUMP PROFILING SUMMARY
# ============================================================
# Initial total Chi2 (before profiling): 0.0000
# Profiled total Chi2 (after profiling): 0.0000
# Delta Chi2 reduction:                 0.0000
#
# Predicted Observables & Uncertainties (Before vs After):
#   Obs ID   | Original Value  Original Error  | Profiled Value  Profiled Error
# --------------------------------------------------------------------------------
#   1        | 2.868100e-01    8.941600e-02    | 2.868100e-01    2.731000e-02
# ============================================================
#
# LHAPDF 6.5.4 loading all 101 PDFs in set mid_0.4000_wid_0.1000
#   Profiling complete (28/35)mid_0.4000_wid_0.1000, version 1; 101 PDF members
#
#   original  101/101
#   profiled  101/101
#   σ_before=0.089416  σ_after=0.02731  ratio=0.3054
#
# (29/35) [mid_0.4000_wid_0.1250]  x=[0.3375, 0.4625]  central=0.289328  stat=0.0289328
# LHAPDF 6.5.4 loading all 101 PDFs in set JAMDiFF23-transversity_lo_nolat_hessian_50
# JAMDiFF23-transversity_lo_nolat_hessian_50, version 1; 101 PDF members
# Executing ePump profiling: /w/ceph24/JAM/dadamiak/ePump/ePump_kp20221218/src/UpdatePDFs mid_0.4000_wid_0.1250 (cwd=/w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.4000_wid_0.1250) ...
# ePump executed successfully. Parsing results from /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.4000_wid_0.1250/mid_0.4000_wid_0.1250.out...
#
# ============================================================
#                     E-PUMP PROFILING SUMMARY
# ============================================================
# Initial total Chi2 (before profiling): 0.0000
# Profiled total Chi2 (after profiling): 0.0000
# Delta Chi2 reduction:                 0.0000
#
# Predicted Observables & Uncertainties (Before vs After):
#   Obs ID   | Original Value  Original Error  | Profiled Value  Profiled Error
# --------------------------------------------------------------------------------
#   1        | 2.893300e-01    8.901100e-02    | 2.893300e-01    2.751600e-02
# ============================================================
#
# LHAPDF 6.5.4 loading all 101 PDFs in set mid_0.4000_wid_0.1250
#   Profiling complete (29/35)
# mid_0.4000_wid_0.1250, version 1; 101 PDF members
#   original  101/101
#   profiled  101/101
#   σ_before=0.089011  σ_after=0.027515  ratio=0.3091
#
# (30/35) [mid_0.4000_wid_0.1500]  x=[0.3250, 0.4750]  central=0.292394  stat=0.0292394
# LHAPDF 6.5.4 loading all 101 PDFs in set JAMDiFF23-transversity_lo_nolat_hessian_50
# JAMDiFF23-transversity_lo_nolat_hessian_50, version 1; 101 PDF members
# Executing ePump profiling: /w/ceph24/JAM/dadamiak/ePump/ePump_kp20221218/src/UpdatePDFs mid_0.4000_wid_0.1500 (cwd=/w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.4000_wid_0.1500) ...
# ePump executed successfully. Parsing results from /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.4000_wid_0.1500/mid_0.4000_wid_0.1500.out...
#
# ============================================================
#                     E-PUMP PROFILING SUMMARY
# ============================================================
# Initial total Chi2 (before profiling): 0.0000
# Profiled total Chi2 (after profiling): 0.0000
# Delta Chi2 reduction:                 0.0000
#
# Predicted Observables & Uncertainties (Before vs After):
#   Obs ID   | Original Value  Original Error  | Profiled Value  Profiled Error
# --------------------------------------------------------------------------------
#   1        | 2.923900e-01    8.852300e-02    | 2.923900e-01    2.776400e-02
# ============================================================
#
# LHAPDF 6.5.4 loading all 101 PDFs in set mid_0.4000_wid_0.1500
#   Profiling complete (30/35)mid_0.4000_wid_0.1500, version 1; 101 PDF members
#
#   original  101/101
#   profiled  101/101
#   σ_before=0.088523  σ_after=0.027764  ratio=0.3136
#
# (31/35) [mid_0.4500_wid_0.0500]  x=[0.4250, 0.4750]  central=0.189271  stat=0.0189271
# LHAPDF 6.5.4 loading all 101 PDFs in set JAMDiFF23-transversity_lo_nolat_hessian_50
# JAMDiFF23-transversity_lo_nolat_hessian_50, version 1; 101 PDF members
# Executing ePump profiling: /w/ceph24/JAM/dadamiak/ePump/ePump_kp20221218/src/UpdatePDFs mid_0.4500_wid_0.0500 (cwd=/w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.4500_wid_0.0500) ...
# ePump executed successfully. Parsing results from /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/mid_0.4500_wid_0.0500/mid_0.4500_wid_0.0500.out...
#
# ============================================================
#                     E-PUMP PROFILING SUMMARY
# ============================================================
# Initial total Chi2 (before profiling): 0.0000
# Profiled total Chi2 (after profiling): 0.0000
# Delta Chi2 reduction:                 0.0000
#
# Predicted Observables & Uncertainties (Before vs After):
#   Obs ID   | Original Value  Original Error  | Profiled Value  Profiled Error
# --------------------------------------------------------------------------------
#   1        | 1.892700e-01    7.632900e-02    | 1.892700e-01    1.837100e-02
# ============================================================
#
# LHAPDF 6.5.4 loading all 101 PDFs in set mid_0.4500_wid_0.0500
#   Profiling complete (31/35)mid_0.4500_wid_0.0500, version 1; 101 PDF members
#
#   original  101/101
#   profiled  101/101
#   σ_before=0.076329  σ_after=0.018371  ratio=0.2407
#
# (32/35) [mid_0.4500_wid_0.0750]  x=[0.4125, 0.4875]  central=0.190469  stat=0.0190469
# LHAPDF 6.5.4 loading all 101 PDFs in set JAMDiFF23-transversity_lo_nolat_hessian_50
# JAMDiFF23-transversity_lo_nolat_hessian_50, version 1; 101 PDF members
# ...
#
# ============================================================
#                     E-PUMP PROFILING SUMMARY
# ============================================================
# Initial total Chi2 (before profiling): 0.0000
# Profiled total Chi2 (after profiling): 0.0000
# Delta Chi2 reduction:                 0.0000
#
# Predicted Observables & Uncertainties (Before vs After):
#   Obs ID   | Original Value  Original Error  | Profiled Value  Profiled Error
# --------------------------------------------------------------------------------
#   1        | 5.745300e-01    1.146800e-01    | 5.745300e-01    8.961800e-02
# ============================================================
#
# LHAPDF 6.5.4 loading all 101 PDFs in set mid_0.3000_wid_0.1500
#   Profiling complete (20/35)
# mid_0.3000_wid_0.1500, version 1; 101 PDF members
#   original  101/101
#   profiled  101/101
#   σ_before=0.11468  σ_after=0.089618  ratio=0.7815
#
# (21/35) [mid_0.3500_wid_0.0500]  x=[0.3250, 0.3750]  central=0.408367  stat=0.102092
# LHAPDF 6.5.4 loading all 101 PDFs in set JAMDiFF23-transversity_lo_nolat_hessian_50
# JAMDiFF23-transversity_lo_nolat_hessian_50, version 1; 101 PDF members
# Executing ePump profiling: /w/ceph24/JAM/dadamiak/ePump/ePump_kp20221218/src/UpdatePDFs mid_0.3500_wid_0.0500 (cwd=/w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.25/mid_0.3500_wid_0.0500) ...
# ePump executed successfully. Parsing results from /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.25/mid_0.3500_wid_0.0500/mid_0.3500_wid_0.0500.out...
#
# ============================================================
#                     E-PUMP PROFILING SUMMARY
# ============================================================
# Initial total Chi2 (before profiling): 0.0000
# Profiled total Chi2 (after profiling): 0.0000
# Delta Chi2 reduction:                 0.0000
#
# Predicted Observables & Uncertainties (Before vs After):
#   Obs ID   | Original Value  Original Error  | Profiled Value  Profiled Error
# --------------------------------------------------------------------------------
#   1        | 4.083700e-01    1.018600e-01    | 4.083700e-01    7.210900e-02
# ============================================================
#
# LHAPDF 6.5.4 loading all 101 PDFs in set mid_0.3500_wid_0.0500
#   Profiling complete (21/35)
# mid_0.3500_wid_0.0500, version 1; 101 PDF members
#   original  101/101
#   profiled  101/101
#   σ_before=0.10186  σ_after=0.072109  ratio=0.7079
#
# (22/35) [mid_0.3500_wid_0.0750]  x=[0.3125, 0.3875]  central=0.409878  stat=0.10247
# LHAPDF 6.5.4 loading all 101 PDFs in set JAMDiFF23-transversity_lo_nolat_hessian_50
# JAMDiFF23-transversity_lo_nolat_hessian_50, version 1; 101 PDF members
# Executing ePump profiling: /w/ceph24/JAM/dadamiak/ePump/ePump_kp20221218/src/UpdatePDFs mid_0.3500_wid_0.0750 (cwd=/w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.25/mid_0.3500_wid_0.0750) ...
# ePump executed successfully. Parsing results from /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.25/mid_0.3500_wid_0.0750/mid_0.3500_wid_0.0750.out...
#
# ============================================================
#                     E-PUMP PROFILING SUMMARY
# ============================================================
# Initial total Chi2 (before profiling): 0.0000
# Profiled total Chi2 (after profiling): 0.0000
# Delta Chi2 reduction:                 0.0000
#
# Predicted Observables & Uncertainties (Before vs After):
#   Obs ID   | Original Value  Original Error  | Profiled Value  Profiled Error
# --------------------------------------------------------------------------------
#   1        | 4.098800e-01    1.015800e-01    | 4.098800e-01    7.214100e-02
# ============================================================
#
# LHAPDF 6.5.4 loading all 101 PDFs in set mid_0.3500_wid_0.0750
#   Profiling complete (22/35)
# mid_0.3500_wid_0.0750, version 1; 101 PDF members
#   original  101/101
#   profiled  101/101
#   σ_before=0.10158  σ_after=0.072141  ratio=0.7102
#
# (23/35) [mid_0.3500_wid_0.1000]  x=[0.3000, 0.4000]  central=0.41198  stat=0.102995
# LHAPDF 6.5.4 loading all 101 PDFs in set JAMDiFF23-transversity_lo_nolat_hessian_50
# JAMDiFF23-transversity_lo_nolat_hessian_50, version 1; 101 PDF members
# Executing ePump profiling: /w/ceph24/JAM/dadamiak/ePump/ePump_kp20221218/src/UpdatePDFs mid_0.3500_wid_0.1000 (cwd=/w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.25/mid_0.3500_wid_0.1000) ...
# ePump executed successfully. Parsing results from /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.25/mid_0.3500_wid_0.1000/mid_0.3500_wid_0.1000.out...
#
# ============================================================
#                     E-PUMP PROFILING SUMMARY
# ============================================================
# Initial total Chi2 (before profiling): 0.0000
# Profiled total Chi2 (after profiling): 0.0000
# Delta Chi2 reduction:                 0.0000
#
# Predicted Observables & Uncertainties (Before vs After):
#   Obs ID   | Original Value  Original Error  | Profiled Value  Profiled Error
# --------------------------------------------------------------------------------
#   1        | 4.119800e-01    1.011900e-01    | 4.119800e-01    7.218400e-02
# ============================================================
#
# LHAPDF 6.5.4 loading all 101 PDFs in set mid_0.3500_wid_0.1000
#   Profiling complete (23/35)
# mid_0.3500_wid_0.1000, version 1; 101 PDF members
#   original  101/101
#   profiled  101/101
#   σ_before=0.10119  σ_after=0.072184  ratio=0.7133
#
# (24/35) [mid_0.3500_wid_0.1250]  x=[0.2875, 0.4125]  central=0.414662  stat=0.103666
# LHAPDF 6.5.4 loading all 101 PDFs in set JAMDiFF23-transversity_lo_nolat_hessian_50
# JAMDiFF23-transversity_lo_nolat_hessian_50, version 1; 101 PDF members
# Executing ePump profiling: /w/ceph24/JAM/dadamiak/ePump/ePump_kp20221218/src/UpdatePDFs mid_0.3500_wid_0.1250 (cwd=/w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.25/mid_0.3500_wid_0.1250) ...
# ePump executed successfully. Parsing results from /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.25/mid_0.3500_wid_0.1250/mid_0.3500_wid_0.1250.out...
#
# ============================================================
#                     E-PUMP PROFILING SUMMARY
# ============================================================
# Initial total Chi2 (before profiling): 0.0000
# Profiled total Chi2 (after profiling): 0.0000
# Delta Chi2 reduction:                 0.0000
#
# Predicted Observables & Uncertainties (Before vs After):
#   Obs ID   | Original Value  Original Error  | Profiled Value  Profiled Error
# --------------------------------------------------------------------------------
#   1        | 4.146600e-01    1.007100e-01    | 4.146600e-01    7.223700e-02
# ============================================================
#
# LHAPDF 6.5.4 loading all 101 PDFs in set mid_0.3500_wid_0.1250
#   Profiling complete (24/35)
# mid_0.3500_wid_0.1250, version 1; 101 PDF members
#   original  101/101
#   profiled  101/101
#   σ_before=0.10071  σ_after=0.072237  ratio=0.7172
#
# (25/35) [mid_0.3500_wid_0.1500]  x=[0.2750, 0.4250]  central=0.417909  stat=0.104477
# LHAPDF 6.5.4 loading all 101 PDFs in set JAMDiFF23-transversity_lo_nolat_hessian_50
# JAMDiFF23-transversity_lo_nolat_hessian_50, version 1; 101 PDF members
# Executing ePump profiling: /w/ceph24/JAM/dadamiak/ePump/ePump_kp20221218/src/UpdatePDFs mid_0.3500_wid_0.1500 (cwd=/w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.25/mid_0.3500_wid_0.1500) ...
# ePump executed successfully. Parsing results from /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.25/mid_0.3500_wid_0.1500/mid_0.3500_wid_0.1500.out...
#
# ============================================================
#                     E-PUMP PROFILING SUMMARY
# ============================================================
# Initial total Chi2 (before profiling): 0.0000
# Profiled total Chi2 (after profiling): 0.0000
# Delta Chi2 reduction:                 0.0000
#
# Predicted Observables & Uncertainties (Before vs After):
#   Obs ID   | Original Value  Original Error  | Profiled Value  Profiled Error
# --------------------------------------------------------------------------------
#   1        | 4.179100e-01    1.001500e-01    | 4.179100e-01    7.229900e-02
# ============================================================
#
# LHAPDF 6.5.4 loading all 101 PDFs in set mid_0.3500_wid_0.1500
#   Profiling complete (25/35)
# mid_0.3500_wid_0.1500, version 1; 101 PDF members
#   original  101/101
#   profiled  101/101
#   σ_before=0.10015  σ_after=0.072299  ratio=0.7219
#
# (26/35) [mid_0.4000_wid_0.0500]  x=[0.3750, 0.4250]  central=0.283432  stat=0.0708579
# LHAPDF 6.5.4 loading all 101 PDFs in set JAMDiFF23-transversity_lo_nolat_hessian_50
# JAMDiFF23-transversity_lo_nolat_hessian_50, version 1; 101 PDF members
# Executing ePump profiling: /w/ceph24/JAM/dadamiak/ePump/ePump_kp20221218/src/UpdatePDFs mid_0.4000_wid_0.0500 (cwd=/w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.25/mid_0.4000_wid_0.0500) ...
# ePump executed successfully. Parsing results from /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.25/mid_0.4000_wid_0.0500/mid_0.4000_wid_0.0500.out...
#
# ============================================================
#                     E-PUMP PROFILING SUMMARY
# ============================================================
# Initial total Chi2 (before profiling): 0.0000
# Profiled total Chi2 (after profiling): 0.0000
# Delta Chi2 reduction:                 0.0000
#
# Predicted Observables & Uncertainties (Before vs After):
#   Obs ID   | Original Value  Original Error  | Profiled Value  Profiled Error
# --------------------------------------------------------------------------------
#   1        | 2.834300e-01    8.996400e-02    | 2.834300e-01    5.566500e-02
# ============================================================
#
# LHAPDF 6.5.4 loading all 101 PDFs in set mid_0.4000_wid_0.0500
#   Profiling complete (26/35)
# mid_0.4000_wid_0.0500, version 1; 101 PDF members
#   original  101/101
#   profiled  101/101
#   σ_before=0.089964  σ_after=0.055665  ratio=0.6188
#
# (27/35) [mid_0.4000_wid_0.0750]  x=[0.3625, 0.4375]  central=0.28484  stat=0.0712099
# LHAPDF 6.5.4 loading all 101 PDFs in set JAMDiFF23-transversity_lo_nolat_hessian_50
# JAMDiFF23-transversity_lo_nolat_hessian_50, version 1; 101 PDF members
# Executing ePump profiling: /w/ceph24/JAM/dadamiak/ePump/ePump_kp20221218/src/UpdatePDFs mid_0.4000_wid_0.0750 (cwd=/w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.25/mid_0.4000_wid_0.0750) ...
# ePump executed successfully. Parsing results from /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.25/mid_0.4000_wid_0.0750/mid_0.4000_wid_0.0750.out...
#
# ============================================================
#                     E-PUMP PROFILING SUMMARY
# ============================================================
# Initial total Chi2 (before profiling): 0.0000
# Profiled total Chi2 (after profiling): 0.0000
# Delta Chi2 reduction:                 0.0000
#
# Predicted Observables & Uncertainties (Before vs After):
#   Obs ID   | Original Value  Original Error  | Profiled Value  Profiled Error
# --------------------------------------------------------------------------------
#   1        | 2.848400e-01    8.973400e-02    | 2.848400e-01    5.578000e-02
# ============================================================
#
# LHAPDF 6.5.4 loading all 101 PDFs in set mid_0.4000_wid_0.0750
# mid_0.4000_wid_0.0750, version 1; 101 PDF members
#   Profiling complete (27/35)
#   original  101/101
#   profiled  101/101
#   σ_before=0.089734  σ_after=0.05578  ratio=0.6216
#
# (28/35) [mid_0.4000_wid_0.1000]  x=[0.3500, 0.4500]  central=0.286808  stat=0.071702
# LHAPDF 6.5.4 loading all 101 PDFs in set JAMDiFF23-transversity_lo_nolat_hessian_50
# JAMDiFF23-transversity_lo_nolat_hessian_50, version 1; 101 PDF members
# Executing ePump profiling: /w/ceph24/JAM/dadamiak/ePump/ePump_kp20221218/src/UpdatePDFs mid_0.4000_wid_0.1000 (cwd=/w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.25/mid_0.4000_wid_0.1000) ...
# ePump executed successfully. Parsing results from /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.25/mid_0.4000_wid_0.1000/mid_0.4000_wid_0.1000.out...
#
# ============================================================
#                     E-PUMP PROFILING SUMMARY
# ============================================================
# Initial total Chi2 (before profiling): 0.0000
# Profiled total Chi2 (after profiling): 0.0000
# Delta Chi2 reduction:                 0.0000
#
# Predicted Observables & Uncertainties (Before vs After):
#   Obs ID   | Original Value  Original Error  | Profiled Value  Profiled Error
# --------------------------------------------------------------------------------
#   1        | 2.868100e-01    8.941600e-02    | 2.868100e-01    5.593800e-02
# ============================================================
#
# LHAPDF 6.5.4 loading all 101 PDFs in set mid_0.4000_wid_0.1000
#   Profiling complete (28/35)
# mid_0.4000_wid_0.1000, version 1; 101 PDF members
#   original  101/101
#   profiled  101/101
#   σ_before=0.089416  σ_after=0.055938  ratio=0.6256
#
# (29/35) [mid_0.4000_wid_0.1250]  x=[0.3375, 0.4625]  central=0.289328  stat=0.072332
# LHAPDF 6.5.4 loading all 101 PDFs in set JAMDiFF23-transversity_lo_nolat_hessian_50
# JAMDiFF23-transversity_lo_nolat_hessian_50, version 1; 101 PDF members
# Executing ePump profiling: /w/ceph24/JAM/dadamiak/ePump/ePump_kp20221218/src/UpdatePDFs mid_0.4000_wid_0.1250 (cwd=/w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.25/mid_0.4000_wid_0.1250) ...
# ePump executed successfully. Parsing results from /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.25/mid_0.4000_wid_0.1250/mid_0.4000_wid_0.1250.out...
#
# ============================================================
#                     E-PUMP PROFILING SUMMARY
# ============================================================
# Initial total Chi2 (before profiling): 0.0000
# Profiled total Chi2 (after profiling): 0.0000
# Delta Chi2 reduction:                 0.0000
#
# Predicted Observables & Uncertainties (Before vs After):
#   Obs ID   | Original Value  Original Error  | Profiled Value  Profiled Error
# --------------------------------------------------------------------------------
#   1        | 2.893300e-01    8.901100e-02    | 2.893300e-01    5.613500e-02
# ============================================================
#
# LHAPDF 6.5.4 loading all 101 PDFs in set mid_0.4000_wid_0.1250
#   Profiling complete (29/35)
# mid_0.4000_wid_0.1250, version 1; 101 PDF members
#   original  101/101
#   profiled  101/101
#   σ_before=0.089011  σ_after=0.056134  ratio=0.6306
#
# (30/35) [mid_0.4000_wid_0.1500]  x=[0.3250, 0.4750]  central=0.292394  stat=0.0730986
# LHAPDF 6.5.4 loading all 101 PDFs in set JAMDiFF23-transversity_lo_nolat_hessian_50
# JAMDiFF23-transversity_lo_nolat_hessian_50, version 1; 101 PDF members
# Executing ePump profiling: /w/ceph24/JAM/dadamiak/ePump/ePump_kp20221218/src/UpdatePDFs mid_0.4000_wid_0.1500 (cwd=/w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.25/mid_0.4000_wid_0.1500) ...
# ePump executed successfully. Parsing results from /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.25/mid_0.4000_wid_0.1500/mid_0.4000_wid_0.1500.out...
#
# ============================================================
#                     E-PUMP PROFILING SUMMARY
# ============================================================
# Initial total Chi2 (before profiling): 0.0000
# Profiled total Chi2 (after profiling): 0.0000
# Delta Chi2 reduction:                 0.0000
#
# Predicted Observables & Uncertainties (Before vs After):
#   Obs ID   | Original Value  Original Error  | Profiled Value  Profiled Error
# --------------------------------------------------------------------------------
#   1        | 2.923900e-01    8.852300e-02    | 2.923900e-01    5.636500e-02
# ============================================================
#
# LHAPDF 6.5.4 loading all 101 PDFs in set mid_0.4000_wid_0.1500
#   Profiling complete (30/35)
# mid_0.4000_wid_0.1500, version 1; 101 PDF members
#   original  16/101

# %%
fig = scanner1.plot()                           # displays inline in Jupyter
# Out:
# Heat map → /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.1/heatmap.pdf

# %%
fig = scanner2.plot()
# Out:
# Heat map → /w/ceph24/JAM/dadamiak/ePump/scan_results_n_2_u_0.1/heatmap.pdf

# %%
fig = scanner3.plot()
# Out:
# Heat map → /w/ceph24/JAM/dadamiak/ePump/scan_results_n_1_u_0.25/heatmap.pdf
